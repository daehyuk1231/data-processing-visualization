# %% [markdown]
# ### CSV 파일 로딩

# %%
import pandas as pd

file_path = "sec16_data_board.csv"
dataframe = pd.read_csv(file_path)
dataframe
# Out:
#    No Title Content Writer        Date
# 0   1   제목1     내용1   글쓴이1  2025.01.12
# 1   2   제목2     내용2   글쓴이2  2025.01.13
# 2   3   제목3     내용3   글쓴이3  2025.01.14
# 3   4   제목4     내용4   글쓴이4  2025.01.15
# 4   5   제목5     내용5   글쓴이5  2025.01.16

# %% [markdown]
# ### CSV 파일 저장

# %%
dataframe = pd.DataFrame({
    "eno": [1, 2, 3, 4, 5],
    "name": ["춘봄이", "하여름", "추가을", "춘순이", "김철수"],
    "dept": ["개발팀", "분석팀", "홍보팀", "설계팀", "개발팀"],
    "date": pd.to_datetime([
        "2015-09-22", "2016-09-22", "2017-09-22",
        "2019-09-22", "2020-03-15"
    ]),
    "salary": [8000, 7500, 7300, 7700, 7100],
    "bonus": [100, 200, 300, 500, 250]
})
file_path = "sec16_data_employee.csv"
dataframe.to_csv(file_path, index=False)
